# %% [markdown]
# <a href="https://colab.research.google.com/github/SreenidhiManikantan/Myntra-/blob/main/My_Personal_Assitant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
! pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2024.7.4)
# Downloading gTTS-2.5.2-py3-none-any.whl (29 kB)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.5.2

# %%
import pathlib
import textwrap
from gtts import gTTS

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown
from IPython.display import Audio, display


GOOGLE_API_KEY = "AIzaSyDibilTFewgVPVcL43oootzlBwLWXCVeUA"

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

genai.configure(api_key=GOOGLE_API_KEY)

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
model = genai.GenerativeModel('gemini-pro')

# %%
#Step 1
def ask_question(name):
  ques = 'Hey '+  name +' what do you want ? '
  ques = input(ques)
  return ques

# %%
def classify_questions(ques):
  goahead_with_web_search = False
  device_lst = ['alarm','remainder','message','call']
  personal_lst = ['who are you?','who created you?']

  device = False
  for i in device_lst:
    if i in ques:
      device = True

  if device:
    print("This question is related to Device things,which is not support in our google assistant!")

  personal_question = False
  for i in personal_lst:
   if i in ques.lower():
    personal_question = True

  if personal_question:
    print("Hey am a personal assistant created by Sreenidhi")



  if device:
    goahead_with_web_search = False

  elif personal_question:
    goahead_with_web_search = False

  else:
    goahead_with_web_search = True

  return goahead_with_web_search

# %%
classify_questions("Who are you?")
# Out:
# Hey am a personal assistant created by Sreenidhi
# False

# %%
#Start searching wth google gemeni

# %%
def ask_gemini(ques):
  response = model.generate_content(ques)
  to_markdown(response.text)
  return response.text

# %%
def speak(answer):
   tts = gTTS(answer)
   tts.save('audio.mp3')
   display(Audio('audio.mp3', autoplay=True))

# %%
have_any_other_ques = 'y'
name = ''

while have_any_other_ques == 'y':
    if name == '':
        name = input("Hey what is your name?-")

    q = ask_question(name)
    go_ahead = classify_questions(q)
    answer = ''

    if go_ahead:
            answer = ask_gemini(q)
            speak(answer)
            print(answer)


    have_any_other_ques = input("Do you have any other questions? ")
# Out:
# Hey what is your name?-Sree
# Hey Sree what do you want ? Make me a tea
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# **Ingredients:**
#
# * 1 teabag of your choice (e.g., black tea, green tea, herbal tea)
# * 1 cup (8 ounces) of boiling water
# * Sugar or honey (optional)
# * Milk or lemon (optional)
#
# **Instructions:**
#
# 1. Place the teabag in a teapot or teacup.
# 2. Pour the boiling water over the teabag.
# 3. Steep for the desired amount of time, according to the teabag instructions (e.g., 3-5 minutes for black tea, 1-2 minutes for green tea).
# 4. Remove the teabag.
# 5. Add sugar or honey to taste, if desired.
# 6. Add milk or lemon to taste, if desired.
#
# **Variations:**
#
# * **Herbal tea:** Use a blend of herbs, such as chamomile, lavender, or mint.
# * **Flavored tea:** Use a teabag with added flavors, such as Earl Grey, jasmine, or peach.
# * **Honey tea:** Add a tablespoon of honey to the tea for a sweet and soothing flavor.
# * **Lemon tea:** Add a squeeze of fresh lemon juice to the tea for a refreshing and tart flavor.
# * **Milk tea:** Add a splash of milk to the tea for a creamy and rich flavor.
# Do you have any other questions? y
# Hey Sree what do you want ? Set an alarm
# This question is related to Device things,which is not support in our google assistant!
# Do you have any other questions? y
# Hey Sree what do you want ? Make a call
# This question is related to Device things,which is not support in our google assistant!
